# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = "C:/Users/Dell/Desktop/bakery/Bakery.csv"
df = pd.read_csv(file)
df
# Out:
#        TransactionNo          Items             DateTime    Daypart  DayType
# 0                  1          Bread  2016-10-30 09:58:11    Morning  Weekend
# 1                  2   Scandinavian  2016-10-30 10:05:34    Morning  Weekend
# 2                  2   Scandinavian  2016-10-30 10:05:34    Morning  Weekend
# 3                  3  Hot chocolate  2016-10-30 10:07:57    Morning  Weekend
# 4                  3            Jam  2016-10-30 10:07:57    Morning  Weekend
# ...              ...            ...                  ...        ...      ...
# 20502           9682         Coffee  2017-09-04 14:32:58  Afternoon  Weekend
# 20503           9682            Tea  2017-09-04 14:32:58  Afternoon  Weekend
# 20504           9683         Coffee  2017-09-04 14:57:06  Afternoon  Weekend
# 20505           9683         Pastry  2017-09-04 14:57:06  Afternoon  Weekend
# 20506           9684      Smoothies  2017-09-04 15:04:24  Afternoon  Weekend
#
# [20507 rows x 5 columns]

# %%
#first 10 rows
df.head(10)
# Out:
#    TransactionNo          Items             DateTime  Daypart  DayType
# 0              1          Bread  2016-10-30 09:58:11  Morning  Weekend
# 1              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 2              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 3              3  Hot chocolate  2016-10-30 10:07:57  Morning  Weekend
# 4              3            Jam  2016-10-30 10:07:57  Morning  Weekend
# 5              3        Cookies  2016-10-30 10:07:57  Morning  Weekend
# 6              4         Muffin  2016-10-30 10:08:41  Morning  Weekend
# 7              5         Coffee  2016-10-30 10:13:03  Morning  Weekend
# 8              5         Pastry  2016-10-30 10:13:03  Morning  Weekend
# 9              5          Bread  2016-10-30 10:13:03  Morning  Weekend

# %%
#last 10 rows
df.tail(10)
# Out:
#        TransactionNo             Items             DateTime    Daypart  \
# 20497           9681               Tea  2017-09-04 14:30:09  Afternoon
# 20498           9681    Spanish Brunch  2017-09-04 14:30:09  Afternoon
# 20499           9681  Christmas common  2017-09-04 14:30:09  Afternoon
# 20500           9682            Muffin  2017-09-04 14:32:58  Afternoon
# 20501           9682      Tacos/Fajita  2017-09-04 14:32:58  Afternoon
# 20502           9682            Coffee  2017-09-04 14:32:58  Afternoon
# 20503           9682               Tea  2017-09-04 14:32:58  Afternoon
# 20504           9683            Coffee  2017-09-04 14:57:06  Afternoon
# 20505           9683            Pastry  2017-09-04 14:57:06  Afternoon
# 20506           9684         Smoothies  2017-09-04 15:04:24  Afternoon
#
#        DayType
# 20497  Weekend
# 20498  Weekend
# 20499  Weekend
# 20500  Weekend
# 20501  Weekend
# 20502  Weekend
# 20503  Weekend
# 20504  Weekend
# 20505  Weekend
# 20506  Weekend

# %%
#overview of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20507 entries, 0 to 20506
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionNo  20507 non-null  int64
#  1   Items          20507 non-null  object
#  2   DateTime       20507 non-null  object
#  3   Daypart        20507 non-null  object
#  4   DayType        20507 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 801.2+ KB

# %%
# df for data frame
# info() used for getting information of dataset/ data from set.

# %%
df.describe()
# Out:
#        TransactionNo
# count   20507.000000
# mean     4976.202370
# std      2796.203001
# min         1.000000
# 25%      2552.000000
# 50%      5137.000000
# 75%      7357.000000
# max      9684.000000

# %%
#checking duplicates
if df.duplicated().sum() > 0 :
    print('Duplicates are present')
else:
    print('No duplicates exists')
# Out:
# Duplicates are present

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 20502    False
# 20503    False
# 20504    False
# 20505    False
# 20506    False
# Length: 20507, dtype: bool

# %%
#dropping duplicates
df.drop_duplicates(inplace = True)
df.head(10)
df.drop_duplicates(inplace = True)
df.head(10)
# Out:
#     TransactionNo          Items             DateTime  Daypart  DayType
# 0               1          Bread  2016-10-30 09:58:11  Morning  Weekend
# 1               2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 3               3  Hot chocolate  2016-10-30 10:07:57  Morning  Weekend
# 4               3            Jam  2016-10-30 10:07:57  Morning  Weekend
# 5               3        Cookies  2016-10-30 10:07:57  Morning  Weekend
# 6               4         Muffin  2016-10-30 10:08:41  Morning  Weekend
# 7               5         Coffee  2016-10-30 10:13:03  Morning  Weekend
# 8               5         Pastry  2016-10-30 10:13:03  Morning  Weekend
# 9               5          Bread  2016-10-30 10:13:03  Morning  Weekend
# 10              6      Medialuna  2016-10-30 10:16:55  Morning  Weekend

# %%
if df.duplicated().sum() > 0 :
    print('Duplicates are present')
else:
    print('No duplicates exists')
# Out:
# No duplicates exists

# %% [markdown]
# # 1.item frequency analysis

# %%
df
# Out:
#        TransactionNo          Items             DateTime    Daypart  DayType
# 0                  1          Bread  2016-10-30 09:58:11    Morning  Weekend
# 1                  2   Scandinavian  2016-10-30 10:05:34    Morning  Weekend
# 3                  3  Hot chocolate  2016-10-30 10:07:57    Morning  Weekend
# 4                  3            Jam  2016-10-30 10:07:57    Morning  Weekend
# 5                  3        Cookies  2016-10-30 10:07:57    Morning  Weekend
# ...              ...            ...                  ...        ...      ...
# 20502           9682         Coffee  2017-09-04 14:32:58  Afternoon  Weekend
# 20503           9682            Tea  2017-09-04 14:32:58  Afternoon  Weekend
# 20504           9683         Coffee  2017-09-04 14:57:06  Afternoon  Weekend
# 20505           9683         Pastry  2017-09-04 14:57:06  Afternoon  Weekend
# 20506           9684      Smoothies  2017-09-04 15:04:24  Afternoon  Weekend
#
# [18887 rows x 5 columns]

# %%
item_count = df["Items"].value_counts().reset_index()
print(item_count)
# Out:
#              Items  count
# 0           Coffee   4528
# 1            Bread   3097
# 2              Tea   1350
# 3             Cake    983
# 4           Pastry    815
# ..             ...    ...
# 89           Bacon      1
# 90    Gift voucher      1
# 91  Olum & polenta      1
# 92        Raw bars      1
# 93         Polenta      1
#
# [94 rows x 2 columns]

# %%
#Renaming the column
rename_columns = item_count.rename(columns = {'Items':'Item_list', 'count':'Frequency'})
print(rename_columns)
# Out:
#          Item_list  Frequency
# 0           Coffee       4528
# 1            Bread       3097
# 2              Tea       1350
# 3             Cake        983
# 4           Pastry        815
# ..             ...        ...
# 89           Bacon          1
# 90    Gift voucher          1
# 91  Olum & polenta          1
# 92        Raw bars          1
# 93         Polenta          1
#
# [94 rows x 2 columns]

# %%
#plotting a horizontal bar

items = rename_columns['Item_list']
frequency = rename_columns['Frequency']

fig , ax =plt.subplots(figsize = (10,50))
ax.barh(items, frequency)

ax.set_title('Item Frequency Analysis')
ax.set_xlabel('Frenquency')
ax.set_ylabel('Items')

plt.show()

# %%
df
# Out:
#        TransactionNo          Items             DateTime    Daypart  DayType
# 0                  1          Bread  2016-10-30 09:58:11    Morning  Weekend
# 1                  2   Scandinavian  2016-10-30 10:05:34    Morning  Weekend
# 3                  3  Hot chocolate  2016-10-30 10:07:57    Morning  Weekend
# 4                  3            Jam  2016-10-30 10:07:57    Morning  Weekend
# 5                  3        Cookies  2016-10-30 10:07:57    Morning  Weekend
# ...              ...            ...                  ...        ...      ...
# 20502           9682         Coffee  2017-09-04 14:32:58  Afternoon  Weekend
# 20503           9682            Tea  2017-09-04 14:32:58  Afternoon  Weekend
# 20504           9683         Coffee  2017-09-04 14:57:06  Afternoon  Weekend
# 20505           9683         Pastry  2017-09-04 14:57:06  Afternoon  Weekend
# 20506           9684      Smoothies  2017-09-04 15:04:24  Afternoon  Weekend
#
# [18887 rows x 5 columns]

# %% [markdown]
# # 3.daypart analysis

# %%
daypart_frequency = df['Daypart'].value_counts().reset_index()
print(daypart_frequency)
# Out:
#      Daypart  count
# 0  Afternoon  10687
# 1    Morning   7697
# 2    Evening    490
# 3      Night     13

# %%
renamed_daypart = daypart_frequency.rename(columns = {'count':'No_of_transactions'})
print(renamed_daypart)
# Out:
#      Daypart  No_of_transactions
# 0  Afternoon               10687
# 1    Morning                7697
# 2    Evening                 490
# 3      Night                  13

# %%
day_part = renamed_daypart['Daypart']
count = renamed_daypart['No_of_transactions']

fig , ax =plt.subplots(figsize = (10,50))
ax.bar(day_part, count)

ax.set_title('Daypart Frequency Analysis')
ax.set_xlabel('day_part')
ax.set_ylabel('count')

plt.show()

# %% [markdown]
# # time series analysis

# %%
df
# Out:
#        TransactionNo          Items             DateTime    Daypart  DayType
# 0                  1          Bread  2016-10-30 09:58:11    Morning  Weekend
# 1                  2   Scandinavian  2016-10-30 10:05:34    Morning  Weekend
# 3                  3  Hot chocolate  2016-10-30 10:07:57    Morning  Weekend
# 4                  3            Jam  2016-10-30 10:07:57    Morning  Weekend
# 5                  3        Cookies  2016-10-30 10:07:57    Morning  Weekend
# ...              ...            ...                  ...        ...      ...
# 20502           9682         Coffee  2017-09-04 14:32:58  Afternoon  Weekend
# 20503           9682            Tea  2017-09-04 14:32:58  Afternoon  Weekend
# 20504           9683         Coffee  2017-09-04 14:57:06  Afternoon  Weekend
# 20505           9683         Pastry  2017-09-04 14:57:06  Afternoon  Weekend
# 20506           9684      Smoothies  2017-09-04 15:04:24  Afternoon  Weekend
#
# [18887 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18887 entries, 0 to 20506
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionNo  18887 non-null  int64
#  1   Items          18887 non-null  object
#  2   DateTime       18887 non-null  object
#  3   Daypart        18887 non-null  object
#  4   DayType        18887 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 885.3+ KB

# %%
# Convert 'DateTime' column to datetime type
df['DateTime'] = pd.to_datetime(df['DateTime'])

# Split 'DateTime' column into 'Date' and 'Time' columns
df['Date'] = df['DateTime'].dt.date
df['Time'] = df['DateTime'].dt.time

# Drop the original 'DateTime' column if needed
# df = df.drop('DateTime', axis=1)

# Display the DataFrame
df
# Out:
#        TransactionNo          Items            DateTime    Daypart  DayType  \
# 0                  1          Bread 2016-10-30 09:58:11    Morning  Weekend
# 1                  2   Scandinavian 2016-10-30 10:05:34    Morning  Weekend
# 3                  3  Hot chocolate 2016-10-30 10:07:57    Morning  Weekend
# 4                  3            Jam 2016-10-30 10:07:57    Morning  Weekend
# 5                  3        Cookies 2016-10-30 10:07:57    Morning  Weekend
# ...              ...            ...                 ...        ...      ...
# 20502           9682         Coffee 2017-09-04 14:32:58  Afternoon  Weekend
# 20503           9682            Tea 2017-09-04 14:32:58  Afternoon  Weekend
# 20504           9683         Coffee 2017-09-04 14:57:06  Afternoon  Weekend
# 20505           9683         Pastry 2017-09-04 14:57:06  Afternoon  Weekend
# 20506           9684      Smoothies 2017-09-04 15:04:24  Afternoon  Weekend
#
#              Date      Time
# 0      2016-10-30  09:58:11
# 1      2016-10-30  10:05:34
# 3      2016-10-30  10:07:57
# 4      2016-10-30  10:07:57
# 5      2016-10-30  10:07:57
# ...           ...       ...
# 20502  2017-09-04  14:32:58
# 20503  2017-09-04  14:32:58
# 20504  2017-09-04  14:57:06
# 20505  2017-09-04  14:57:06
# 20506  2017-09-04  15:04:24
#
# [18887 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18887 entries, 0 to 20506
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionNo  18887 non-null  int64
#  1   Items          18887 non-null  object
#  2   DateTime       18887 non-null  datetime64[ns]
#  3   Daypart        18887 non-null  object
#  4   DayType        18887 non-null  object
#  5   Date           18887 non-null  object
#  6   Time           18887 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 1.2+ MB

# %%
#determine the specific period

start_date = '2016-10-30'
end_date = '2017-09-04'

#filter the dataset
filtered_df = df[(df['DateTime'] >= start_date) & (df['DateTime'] <= end_date)]

#calculate count of transactions in the filtered dataset
transaction_count = filtered_df.shape[0]

print('Total number of transactions : ', transaction_count)
# Out:
# Total number of transactions :  15064

# %%
import datetime

start_date = datetime.datetime.strptime('2016-10-30 09:58:11', '%Y-%m-%d %H:%M:%S')
end_date = datetime.datetime.strptime('2017-09-04 15:04:24', '%Y-%m-%d %H:%M:%S')

#filter the dataset
filtered_df = df[(df['DateTime'] >= start_date) & (df['DateTime'] <= end_date)]
transaction_count = len(filtered_df)

print('Total number of transactions:',transaction_count)
# Out:
# Total number of transactions: 15131

# %%
# cumulative transaction growth over time

df['DateTime'] = pd.to_datetime(df['DateTime'])
df = df.sort_values('Date')
df['CummulativeCount'] = df['TransactionNo'].cumsum()
df
# Out:
#        TransactionNo         Items            DateTime    Daypart  DayType  \
# 401              195  Scandinavian 2016-01-11 11:06:09    Morning  Weekday
# 437              214         Bread 2016-01-11 12:26:43  Afternoon  Weekday
# 438              214           Tea 2016-01-11 12:26:43  Afternoon  Weekday
# 440              215        Pastry 2016-01-11 12:30:30  Afternoon  Weekday
# 441              215        Coffee 2016-01-11 12:30:30  Afternoon  Weekday
# ...              ...           ...                 ...        ...      ...
# 16894           8016        Pastry 2017-12-03 12:32:01  Afternoon  Weekend
# 16895           8017      Baguette 2017-12-03 12:33:04  Afternoon  Weekend
# 16896           8018       Cookies 2017-12-03 12:34:03  Afternoon  Weekend
# 16890           8015         Scone 2017-12-03 12:21:11  Afternoon  Weekend
# 16986           8056      Sandwich 2017-12-03 16:28:00  Afternoon  Weekend
#
#              Date      Time  CummulativeCount
# 401    2016-01-11  11:06:09               195
# 437    2016-01-11  12:26:43               409
# 438    2016-01-11  12:26:43               623
# 440    2016-01-11  12:30:30               838
# 441    2016-01-11  12:30:30              1053
# ...           ...       ...               ...
# 16894  2017-12-03  12:32:01          93478404
# 16895  2017-12-03  12:33:04          93486421
# 16896  2017-12-03  12:34:03          93494439
# 16890  2017-12-03  12:21:11          93502454
# 16986  2017-12-03  16:28:00          93510510
#
# [18887 rows x 8 columns]

# %%
fig, ax = plt.subplots(figsize = (10,6))
ax.fill_between(df['Date'], df['CummulativeCount'],color = 'skyblue', alpha = 0.7)

ax.set_title('Cummulative transaction count over time')
ax.plot(df['Date'], df['CummulativeCount'], color='blue')

ax.set_xlabel('Date')
ax.set_ylabel('CummulativeCount')
plt.xticks(rotation = 45)
# Out:
# (array([16801., 16892., 16983., 17075., 17167., 17257., 17348., 17440.,
#         17532.]),
#  [Text(16801.0, 0, '2016-01'),
#   Text(16892.0, 0, '2016-04'),
#   Text(16983.0, 0, '2016-07'),
#   Text(17075.0, 0, '2016-10'),
#   Text(17167.0, 0, '2017-01'),
#   Text(17257.0, 0, '2017-04'),
#   Text(17348.0, 0, '2017-07'),
#   Text(17440.0, 0, '2017-10'),
#   Text(17532.0, 0, '2018-01')])

# %% [markdown]
# # monthly sales analysis

# %%
df
# Out:
#        TransactionNo         Items            DateTime    Daypart  DayType  \
# 401              195  Scandinavian 2016-01-11 11:06:09    Morning  Weekday
# 437              214         Bread 2016-01-11 12:26:43  Afternoon  Weekday
# 438              214           Tea 2016-01-11 12:26:43  Afternoon  Weekday
# 440              215        Pastry 2016-01-11 12:30:30  Afternoon  Weekday
# 441              215        Coffee 2016-01-11 12:30:30  Afternoon  Weekday
# ...              ...           ...                 ...        ...      ...
# 16894           8016        Pastry 2017-12-03 12:32:01  Afternoon  Weekend
# 16895           8017      Baguette 2017-12-03 12:33:04  Afternoon  Weekend
# 16896           8018       Cookies 2017-12-03 12:34:03  Afternoon  Weekend
# 16890           8015         Scone 2017-12-03 12:21:11  Afternoon  Weekend
# 16986           8056      Sandwich 2017-12-03 16:28:00  Afternoon  Weekend
#
#              Date      Time  CummulativeCount
# 401    2016-01-11  11:06:09               195
# 437    2016-01-11  12:26:43               409
# 438    2016-01-11  12:26:43               623
# 440    2016-01-11  12:30:30               838
# 441    2016-01-11  12:30:30              1053
# ...           ...       ...               ...
# 16894  2017-12-03  12:32:01          93478404
# 16895  2017-12-03  12:33:04          93486421
# 16896  2017-12-03  12:34:03          93494439
# 16890  2017-12-03  12:21:11          93502454
# 16986  2017-12-03  16:28:00          93510510
#
# [18887 rows x 8 columns]

# %%
df['Month'] = df['DateTime'].dt.month
df['Year'] = df['DateTime'].dt.year

monthly_sales = df.groupby(['Year', 'Month'])['TransactionNo'].sum().reset_index()

print(monthly_sales)
# Out:
#     Year  Month  TransactionNo
# 0   2016      1         221247
# 1   2016      2         291583
# 2   2016      3         523297
# 3   2016      4         357475
# 4   2016      5         429128
# 5   2016      6         417158
# 6   2016      7         315789
# 7   2016      8         295622
# 8   2016      9         404075
# 9   2016     10         634189
# 10  2016     11        4324977
# 11  2016     12        7040519
# 12  2017      1       14396021
# 13  2017      2       15093175
# 14  2017      3       21960213
# 15  2017      4        4658238
# 16  2017      5        3369035
# 17  2017      6        2817136
# 18  2017      7        3075342
# 19  2017      8        3389547
# 20  2017      9        2408912
# 21  2017     10        2132901
# 22  2017     11        2901579
# 23  2017     12        2053352

# %%
#separate monthly sales data for each year

sales_2016 = monthly_sales[monthly_sales['Year']==2016]
sales_2017 = monthly_sales[monthly_sales['Year']==2017]

#create and separate the bargraphs for eac year
fig,(ax1, ax2) = plt.subplots(2,1, figsize = (10,10))

#bargraphsfor 2016 sales
ax1.bar(sales_2016['Month'], sales_2016['TransactionNo'])
ax1.set_xticks(range(1,13))
ax1.set_xticklabels(['Jan','Feb', 'Mar', 'April', 'May','June','July','Aug', 'Sep', 'Oct','Nov', 'Dec'])
ax1.set_title('Month Sales Analysis - 2016')
ax1.set_xlabel('Month')
ax1.set_ylabel('Total Sales')

#bargraphsfor 2017 sales
ax2.bar(sales_2017['Month'], sales_2017['TransactionNo'])
ax2.set_xticks(range(1,13))
ax2.set_xticklabels(['Jan','Feb', 'Mar', 'April', 'May','June','July','Aug', 'Sep', 'Oct','Nov', 'Dec'])
ax2.set_title('Month Sales Analysis - 2017')
ax2.set_xlabel('Month')
ax2.set_ylabel('Total Sales')

plt.tight_layout()
plt.show()

# %% [markdown]
# # sales Trend Analysis

# %%
df
# Out:
#        TransactionNo         Items            DateTime    Daypart  DayType  \
# 401              195  Scandinavian 2016-01-11 11:06:09    Morning  Weekday
# 437              214         Bread 2016-01-11 12:26:43  Afternoon  Weekday
# 438              214           Tea 2016-01-11 12:26:43  Afternoon  Weekday
# 440              215        Pastry 2016-01-11 12:30:30  Afternoon  Weekday
# 441              215        Coffee 2016-01-11 12:30:30  Afternoon  Weekday
# ...              ...           ...                 ...        ...      ...
# 16894           8016        Pastry 2017-12-03 12:32:01  Afternoon  Weekend
# 16895           8017      Baguette 2017-12-03 12:33:04  Afternoon  Weekend
# 16896           8018       Cookies 2017-12-03 12:34:03  Afternoon  Weekend
# 16890           8015         Scone 2017-12-03 12:21:11  Afternoon  Weekend
# 16986           8056      Sandwich 2017-12-03 16:28:00  Afternoon  Weekend
#
#              Date      Time  CummulativeCount  Month  Year
# 401    2016-01-11  11:06:09               195      1  2016
# 437    2016-01-11  12:26:43               409      1  2016
# 438    2016-01-11  12:26:43               623      1  2016
# 440    2016-01-11  12:30:30               838      1  2016
# 441    2016-01-11  12:30:30              1053      1  2016
# ...           ...       ...               ...    ...   ...
# 16894  2017-12-03  12:32:01          93478404     12  2017
# 16895  2017-12-03  12:33:04          93486421     12  2017
# 16896  2017-12-03  12:34:03          93494439     12  2017
# 16890  2017-12-03  12:21:11          93502454     12  2017
# 16986  2017-12-03  16:28:00          93510510     12  2017
#
# [18887 rows x 10 columns]

# %%
sales_data = df[['DateTime', 'TransactionNo']]

sales_data.set_index('DateTime', inplace = True)

monthly_sales = sales_data.resample('M').sum()

plt.figure(figsize = (10,6))
plt.plot(monthly_sales.index , monthly_sales['TransactionNo'])
plt.title('Sales Trend Analysis')
plt.xlabel('Time')
plt.ylabel('Sales')

plt.show()
